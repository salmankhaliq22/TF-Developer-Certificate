# %% [markdown]
# # Tensorflow Developer Certificate Preparation
# ___
# ## Introduction to Tensorflow in Python - DataCamp - ML-Scientist-Career-Track - by Isaiah Hull
# ___
# ## Chapter 2.3- Linear Regression

# %% [markdown]
# ### 1. Linear regression
# Now that you understand how to construct loss functions, you're well-equipped to start training models. We'll do that for the first time in this video with a linear regression model.
#
# ### 2. What is a linear regression?
# So what is a linear regression model? We can answer this with a simple illustration. Let's say we want to examine the relationship between house size and price in the King County housing dataset. We might start by plotting the size in square feet against the price in dollars. Note that we've actually plotted the relationship after taking the natural logarithm of each variable, which is useful when we suspect that the relationship is proportional. That is, we might expect an x% increase in size to be associated with a y% increase in price.
# ![2.3.1](./figures/2.3.1.PNG)
#
# A linear regression model assumes that the relationship between these variables can be captured by a line. That is, two parameters--the line's slope and intercept--fully characterize the relationship between size and price.
# ![2.3.2](./figures/2.3.2.PNG)
#
# ### 3. The linear regression model
# In our case, we've assumed that the relationship is linear after taking natural logarithms.
# - Training the model will involve recovering the slope of the line and the intercept, where the line intersects the vertical axis.
# - Once we have trained the intercept and slope, we can take a house's size and predict its price.
# - The difference between the predicted price and actual price is the error, which can be used to construct a loss function.
# - The example we've shown is for a univariate regression, which has only one feature, size.
# - A multiple regression has multiple features, such as size and location.
# ![2.3.3](./figures/2.3.3.PNG)
#
# ### 4. Linear regression in TensorFlow
# Let's look at some code to see how this can be implemented.
# - We will first define our target variable, price, and feature, size.
# - We also initialize the intercept and slope as trainable variables.

# %%
# import numpy and pandas
import numpy as np
import pandas as pd
import tensorflow as tf

# Load data from csv
housing = pd.read_csv('./datasets/kc_house_data.csv')

# Define the targets and features
price = np.array(housing['price'], np.float32)
size = np.array(housing['sqft_living'], np.float32)

# Define the intercept and slope
intercept = tf.Variable(0.1, np.float32)
slope = tf.Variable(0.1, np.float32)

# %% [markdown]
# - After that, we **define the model**, which we'll use to make predictions by multiplying size and slope and then adding the intercept.
# - Again, remember that we can do this using the addition and multiplication symbols, since these are overloaded operators and intercept and slope are tensorflow operations.

# %%
# Define a linear regression model
def linear_regression(intercept, slope = slope, features = size):
    return intercept + features*slope

# %% [markdown]
# - Our **next step** is to define a **loss function**.
# - This function will take the model's parameters and the data as an input.
# - It will first use the model to compute the predicted values.
# - We then set the function to return the mean squared error loss.
# - We, of course, could have selected a different loss.

# %%
# define a loss function to compute the MSE
def loss_function(intercept, slope, targets = price, features = size):
    # compute the predictions for a linear model
    predictions = linear_regression(intercept, slope)
    
    # Return the loss
    return tf.keras.losses.mse(targets, predictions)

# %% [markdown]
# - With the loss function defined, the next step is to **define an optimization operation**.
# - We'll do this using the adam optimizer.
# - For now, you can ignore the choice of optimization algorithm.
# - We will discuss the selection of optimizers in greater detail later.
# - For our purposes, it is sufficient to understand that executing this operation will change the slope and intercept in a direction that will lower the value of the loss.

# %%
# Define an optimization operation
opt = tf.keras.optimizers.Adam()

# %% [markdown]
# - We will next **perform minimization on the loss function using the optimizer**.
# - Notice that we've passed the loss function as a lambda function to the minimize operation.
# - We also supplied a variable list, which contains intercept and slope, the two variables we defined earlier.
# - We will execute our optimization step 1000 times.
# - Printing the loss, we'll see that it tends to decline, moving closer to the minimum value with each step.
# - Finally, we print the intercept and the slope. This is our linear model, which enables us to predict the value of a house given its size.

# %%
# Minimize the loss function and print the loss
for j in range(1000):
    opt.minimize(lambda: loss_function(intercept, slope),\
                            var_list = [intercept, slope])
    print(loss_function(intercept, slope))
# Out:
# tf.Tensor(423483800000.0, shape=(), dtype=float32)
# tf.Tensor(423481150000.0, shape=(), dtype=float32)
# tf.Tensor(423478460000.0, shape=(), dtype=float32)
# tf.Tensor(423475700000.0, shape=(), dtype=float32)
# tf.Tensor(423473000000.0, shape=(), dtype=float32)
# tf.Tensor(423470300000.0, shape=(), dtype=float32)
# tf.Tensor(423467600000.0, shape=(), dtype=float32)
# tf.Tensor(423464900000.0, shape=(), dtype=float32)
# tf.Tensor(423462140000.0, shape=(), dtype=float32)
# tf.Tensor(423459420000.0, shape=(), dtype=float32)
# tf.Tensor(423456740000.0, shape=(), dtype=float32)
# tf.Tensor(423454000000.0, shape=(), dtype=float32)
# tf.Tensor(423451260000.0, shape=(), dtype=float32)
# tf.Tensor(423448580000.0, shape=(), dtype=float32)
# tf.Tensor(423445920000.0, shape=(), dtype=float32)
# tf.Tensor(423443170000.0, shape=(), dtype=float32)
# tf.Tensor(423440480000.0, shape=(), dtype=float32)
# tf.Tensor(423437700000.0, shape=(), dtype=float32)
# tf.Tensor(423435040000.0, shape=(), dtype=float32)
# tf.Tensor(423432360000.0, shape=(), dtype=float32)
# tf.Tensor(423429670000.0, shape=(), dtype=float32)
# tf.Tensor(423426900000.0, shape=(), dtype=float32)
# tf.Tensor(423424200000.0, shape=(), dtype=float32)
# tf.Tensor(423421500000.0, shape=(), dtype=float32)
# tf.Tensor(423418820000.0, shape=(), dtype=float32)
# tf.Tensor(423416100000.0, shape=(), dtype=float32)
# tf.Tensor(423413380000.0, shape=(), dtype=float32)
# tf.Tensor(423410630000.0, shape=(), dtype=float32)
# tf.Tensor(423408000000.0, shape=(), dtype=float32)
# tf.Tensor(423405320000.0, shape=(), dtype=float32)
# tf.Tensor(423402540000.0, shape=(), dtype=float32)
# tf.Tensor(423399850000.0, shape=(), dtype=float32)
# tf.Tensor(423397060000.0, shape=(), dtype=float32)
# tf.Tensor(423394380000.0, shape=(), dtype=float32)
# tf.Tensor(423391660000.0, shape=(), dtype=float32)
# tf.Tensor(423388970000.0, shape=(), dtype=float32)
# tf.Tensor(423386250000.0, shape=(), dtype=float32)
# tf.Tensor(423383560000.0, shape=(), dtype=float32)
# tf.Tensor(423380880000.0, shape=(), dtype=float32)
# tf.Tensor(423378200000.0, shape=(), dtype=float32)
# tf.Tensor(423375470000.0, shape=(), dtype=float32)
# tf.Tensor(423372720000.0, shape=(), dtype=float32)
# tf.Tensor(423370030000.0, shape=(), dtype=float32)
# tf.Tensor(423367300000.0, shape=(), dtype=float32)
# tf.Tensor(423364600000.0, shape=(), dtype=float32)
# tf.Tensor(423361900000.0, shape=(), dtype=float32)
# tf.Tensor(423359220000.0, shape=(), dtype=float32)
# tf.Tensor(423356500000.0, shape=(), dtype=float32)
# tf.Tensor(423353750000.0, shape=(), dtype=float32)
# tf.Tensor(423351120000.0, shape=(), dtype=float32)
# tf.Tensor(423348340000.0, shape=(), dtype=float32)
# tf.Tensor(423345650000.0, shape=(), dtype=float32)
# tf.Tensor(423342930000.0, shape=(), dtype=float32)
# tf.Tensor(423340240000.0, shape=(), dtype=float32)
# tf.Tensor(423337500000.0, shape=(), dtype=float32)
# tf.Tensor(423334770000.0, shape=(), dtype=float32)
# tf.Tensor(423332150000.0, shape=(), dtype=float32)
# tf.Tensor(423329400000.0, shape=(), dtype=float32)
# tf.Tensor(423326680000.0, shape=(), dtype=float32)
# tf.Tensor(423323960000.0, shape=(), dtype=float32)
# tf.Tensor(423321270000.0, shape=(), dtype=float32)
# tf.Tensor(423318600000.0, shape=(), dtype=float32)
# tf.Tensor(423315830000.0, shape=(), dtype=float32)
# tf.Tensor(423313200000.0, shape=(), dtype=float32)
# tf.Tensor(423310430000.0, shape=(), dtype=float32)
# tf.Tensor(423307740000.0, shape=(), dtype=float32)
# tf.Tensor(423304950000.0, shape=(), dtype=float32)
# tf.Tensor(423302270000.0, shape=(), dtype=float32)
# tf.Tensor(423299600000.0, shape=(), dtype=float32)
# tf.Tensor(423296930000.0, shape=(), dtype=float32)
# tf.Tensor(423294170000.0, shape=(), dtype=float32)
# tf.Tensor(423291500000.0, shape=(), dtype=float32)
# tf.Tensor(423288770000.0, shape=(), dtype=float32)
# tf.Tensor(423286050000.0, shape=(), dtype=float32)
# tf.Tensor(423283360000.0, shape=(), dtype=float32)
# tf.Tensor(423280670000.0, shape=(), dtype=float32)
# tf.Tensor(423277900000.0, shape=(), dtype=float32)
# tf.Tensor(423275270000.0, shape=(), dtype=float32)
# tf.Tensor(423272480000.0, shape=(), dtype=float32)
# tf.Tensor(423269800000.0, shape=(), dtype=float32)
# tf.Tensor(423267070000.0, shape=(), dtype=float32)
# tf.Tensor(423264400000.0, shape=(), dtype=float32)
# tf.Tensor(423261700000.0, shape=(), dtype=float32)
# tf.Tensor(423258950000.0, shape=(), dtype=float32)
# tf.Tensor(423256300000.0, shape=(), dtype=float32)
# tf.Tensor(423253500000.0, shape=(), dtype=float32)
# tf.Tensor(423250820000.0, shape=(), dtype=float32)
# tf.Tensor(423248130000.0, shape=(), dtype=float32)
# tf.Tensor(423245450000.0, shape=(), dtype=float32)
# tf.Tensor(423242660000.0, shape=(), dtype=float32)
# tf.Tensor(423239970000.0, shape=(), dtype=float32)
# tf.Tensor(423237300000.0, shape=(), dtype=float32)
# tf.Tensor(423234630000.0, shape=(), dtype=float32)
# tf.Tensor(423231880000.0, shape=(), dtype=float32)
# tf.Tensor(423229200000.0, shape=(), dtype=float32)
# tf.Tensor(423226470000.0, shape=(), dtype=float32)
# tf.Tensor(423223750000.0, shape=(), dtype=float32)
# tf.Tensor(423221070000.0, shape=(), dtype=float32)
# tf.Tensor(423218300000.0, shape=(), dtype=float32)
# tf.Tensor(423215630000.0, shape=(), dtype=float32)
# tf.Tensor(423212970000.0, shape=(), dtype=float32)
# tf.Tensor(423210200000.0, shape=(), dtype=float32)
# tf.Tensor(423207500000.0, shape=(), dtype=float32)
# tf.Tensor(423204800000.0, shape=(), dtype=float32)
# tf.Tensor(423202130000.0, shape=(), dtype=float32)
# tf.Tensor(423199400000.0, shape=(), dtype=float32)
# tf.Tensor(423196660000.0, shape=(), dtype=float32)
# tf.Tensor(423193970000.0, shape=(), dtype=float32)
# tf.Tensor(423191280000.0, shape=(), dtype=float32)
# tf.Tensor(423188560000.0, shape=(), dtype=float32)
# tf.Tensor(423185840000.0, shape=(), dtype=float32)
# tf.Tensor(423183160000.0, shape=(), dtype=float32)
# tf.Tensor(423180370000.0, shape=(), dtype=float32)
# tf.Tensor(423177680000.0, shape=(), dtype=float32)
# tf.Tensor(423175000000.0, shape=(), dtype=float32)
# tf.Tensor(423172300000.0, shape=(), dtype=float32)
# tf.Tensor(423169600000.0, shape=(), dtype=float32)
# tf.Tensor(423166900000.0, shape=(), dtype=float32)
# tf.Tensor(423164180000.0, shape=(), dtype=float32)
# tf.Tensor(423161500000.0, shape=(), dtype=float32)
# tf.Tensor(423158740000.0, shape=(), dtype=float32)
# tf.Tensor(423156020000.0, shape=(), dtype=float32)
# tf.Tensor(423153400000.0, shape=(), dtype=float32)
# tf.Tensor(423150650000.0, shape=(), dtype=float32)
# tf.Tensor(423147930000.0, shape=(), dtype=float32)
# tf.Tensor(423145200000.0, shape=(), dtype=float32)
# tf.Tensor(423142520000.0, shape=(), dtype=float32)
# tf.Tensor(423139840000.0, shape=(), dtype=float32)
# tf.Tensor(423137080000.0, shape=(), dtype=float32)
# tf.Tensor(423134430000.0, shape=(), dtype=float32)
# tf.Tensor(423131680000.0, shape=(), dtype=float32)
# tf.Tensor(423129000000.0, shape=(), dtype=float32)
# tf.Tensor(423126270000.0, shape=(), dtype=float32)
# tf.Tensor(423123520000.0, shape=(), dtype=float32)
# tf.Tensor(423120860000.0, shape=(), dtype=float32)
# tf.Tensor(423118180000.0, shape=(), dtype=float32)
# tf.Tensor(423115420000.0, shape=(), dtype=float32)
# tf.Tensor(423112740000.0, shape=(), dtype=float32)
# tf.Tensor(423110020000.0, shape=(), dtype=float32)
# tf.Tensor(423107330000.0, shape=(), dtype=float32)
# tf.Tensor(423104600000.0, shape=(), dtype=float32)
# tf.Tensor(423101860000.0, shape=(), dtype=float32)
# tf.Tensor(423099200000.0, shape=(), dtype=float32)
# tf.Tensor(423096520000.0, shape=(), dtype=float32)
# tf.Tensor(423093730000.0, shape=(), dtype=float32)
# tf.Tensor(423091040000.0, shape=(), dtype=float32)
# tf.Tensor(423088360000.0, shape=(), dtype=float32)
# tf.Tensor(423085640000.0, shape=(), dtype=float32)
# tf.Tensor(423082980000.0, shape=(), dtype=float32)
# tf.Tensor(423080200000.0, shape=(), dtype=float32)
# tf.Tensor(423077540000.0, shape=(), dtype=float32)
# tf.Tensor(423074800000.0, shape=(), dtype=float32)
# tf.Tensor(423072070000.0, shape=(), dtype=float32)
# tf.Tensor(423069400000.0, shape=(), dtype=float32)
# tf.Tensor(423066700000.0, shape=(), dtype=float32)
# tf.Tensor(423064000000.0, shape=(), dtype=float32)
# tf.Tensor(423061230000.0, shape=(), dtype=float32)
# tf.Tensor(423058540000.0, shape=(), dtype=float32)
# tf.Tensor(423055900000.0, shape=(), dtype=float32)
# tf.Tensor(423053130000.0, shape=(), dtype=float32)
# tf.Tensor(423050400000.0, shape=(), dtype=float32)
# tf.Tensor(423047730000.0, shape=(), dtype=float32)
# tf.Tensor(423045100000.0, shape=(), dtype=float32)
# tf.Tensor(423042350000.0, shape=(), dtype=float32)
# tf.Tensor(423039630000.0, shape=(), dtype=float32)
# tf.Tensor(423036940000.0, shape=(), dtype=float32)
# tf.Tensor(423034200000.0, shape=(), dtype=float32)
# tf.Tensor(423031540000.0, shape=(), dtype=float32)
# tf.Tensor(423028750000.0, shape=(), dtype=float32)
# tf.Tensor(423026070000.0, shape=(), dtype=float32)
# tf.Tensor(423023380000.0, shape=(), dtype=float32)
# tf.Tensor(423020700000.0, shape=(), dtype=float32)
# tf.Tensor(423017970000.0, shape=(), dtype=float32)
# tf.Tensor(423015300000.0, shape=(), dtype=float32)
# tf.Tensor(423012530000.0, shape=(), dtype=float32)
# tf.Tensor(423009880000.0, shape=(), dtype=float32)
# tf.Tensor(423007200000.0, shape=(), dtype=float32)
# tf.Tensor(423004400000.0, shape=(), dtype=float32)
# tf.Tensor(423001650000.0, shape=(), dtype=float32)
# tf.Tensor(422999030000.0, shape=(), dtype=float32)
# tf.Tensor(422996250000.0, shape=(), dtype=float32)
# tf.Tensor(422993560000.0, shape=(), dtype=float32)
# tf.Tensor(422990870000.0, shape=(), dtype=float32)
# tf.Tensor(422988220000.0, shape=(), dtype=float32)
# tf.Tensor(422985470000.0, shape=(), dtype=float32)
# tf.Tensor(422982780000.0, shape=(), dtype=float32)
# tf.Tensor(422980060000.0, shape=(), dtype=float32)
# tf.Tensor(422977370000.0, shape=(), dtype=float32)
# tf.Tensor(422974700000.0, shape=(), dtype=float32)
# tf.Tensor(422971970000.0, shape=(), dtype=float32)
# tf.Tensor(422969200000.0, shape=(), dtype=float32)
# tf.Tensor(422966560000.0, shape=(), dtype=float32)
# tf.Tensor(422963870000.0, shape=(), dtype=float32)
# tf.Tensor(422961200000.0, shape=(), dtype=float32)
# tf.Tensor(422958400000.0, shape=(), dtype=float32)
# tf.Tensor(422955700000.0, shape=(), dtype=float32)
# tf.Tensor(422953000000.0, shape=(), dtype=float32)
# tf.Tensor(422950240000.0, shape=(), dtype=float32)
# tf.Tensor(422947550000.0, shape=(), dtype=float32)
# tf.Tensor(422944870000.0, shape=(), dtype=float32)
# tf.Tensor(422942200000.0, shape=(), dtype=float32)
# tf.Tensor(422939530000.0, shape=(), dtype=float32)
# tf.Tensor(422936740000.0, shape=(), dtype=float32)
# tf.Tensor(422934000000.0, shape=(), dtype=float32)
# tf.Tensor(422931370000.0, shape=(), dtype=float32)
# tf.Tensor(422928650000.0, shape=(), dtype=float32)
# tf.Tensor(422925960000.0, shape=(), dtype=float32)
# tf.Tensor(422923200000.0, shape=(), dtype=float32)
# tf.Tensor(422920500000.0, shape=(), dtype=float32)
# tf.Tensor(422917770000.0, shape=(), dtype=float32)
# tf.Tensor(422915100000.0, shape=(), dtype=float32)
# tf.Tensor(422912400000.0, shape=(), dtype=float32)
# tf.Tensor(422909700000.0, shape=(), dtype=float32)
# tf.Tensor(422906920000.0, shape=(), dtype=float32)
# tf.Tensor(422904230000.0, shape=(), dtype=float32)
# tf.Tensor(422901550000.0, shape=(), dtype=float32)
# tf.Tensor(422898830000.0, shape=(), dtype=float32)
# tf.Tensor(422896140000.0, shape=(), dtype=float32)
# tf.Tensor(422893420000.0, shape=(), dtype=float32)
# tf.Tensor(422890730000.0, shape=(), dtype=float32)
# tf.Tensor(422888050000.0, shape=(), dtype=float32)
# tf.Tensor(422885330000.0, shape=(), dtype=float32)
# tf.Tensor(422882640000.0, shape=(), dtype=float32)
# tf.Tensor(422879900000.0, shape=(), dtype=float32)
# tf.Tensor(422877230000.0, shape=(), dtype=float32)
# tf.Tensor(422874480000.0, shape=(), dtype=float32)
# tf.Tensor(422871760000.0, shape=(), dtype=float32)
# tf.Tensor(422869070000.0, shape=(), dtype=float32)
# tf.Tensor(422866400000.0, shape=(), dtype=float32)
# tf.Tensor(422863670000.0, shape=(), dtype=float32)
# tf.Tensor(422860980000.0, shape=(), dtype=float32)
# tf.Tensor(422858230000.0, shape=(), dtype=float32)
# tf.Tensor(422855570000.0, shape=(), dtype=float32)
# tf.Tensor(422852900000.0, shape=(), dtype=float32)
# tf.Tensor(422850200000.0, shape=(), dtype=float32)
# tf.Tensor(422847500000.0, shape=(), dtype=float32)
# tf.Tensor(422844730000.0, shape=(), dtype=float32)
# tf.Tensor(422842040000.0, shape=(), dtype=float32)
# tf.Tensor(422839260000.0, shape=(), dtype=float32)
# tf.Tensor(422836570000.0, shape=(), dtype=float32)
# tf.Tensor(422833880000.0, shape=(), dtype=float32)
# tf.Tensor(422831230000.0, shape=(), dtype=float32)
# tf.Tensor(422828440000.0, shape=(), dtype=float32)
# tf.Tensor(422825750000.0, shape=(), dtype=float32)
# tf.Tensor(422823070000.0, shape=(), dtype=float32)
# tf.Tensor(422820380000.0, shape=(), dtype=float32)
# tf.Tensor(422817660000.0, shape=(), dtype=float32)
# tf.Tensor(422815000000.0, shape=(), dtype=float32)
# tf.Tensor(422812320000.0, shape=(), dtype=float32)
# tf.Tensor(422809570000.0, shape=(), dtype=float32)
# tf.Tensor(422806880000.0, shape=(), dtype=float32)
# tf.Tensor(422804130000.0, shape=(), dtype=float32)
# tf.Tensor(422801440000.0, shape=(), dtype=float32)
# tf.Tensor(422798720000.0, shape=(), dtype=float32)
# tf.Tensor(422796030000.0, shape=(), dtype=float32)
# tf.Tensor(422793350000.0, shape=(), dtype=float32)
# tf.Tensor(422790560000.0, shape=(), dtype=float32)
# tf.Tensor(422787900000.0, shape=(), dtype=float32)
# tf.Tensor(422785220000.0, shape=(), dtype=float32)
# tf.Tensor(422782470000.0, shape=(), dtype=float32)
# tf.Tensor(422779750000.0, shape=(), dtype=float32)
# tf.Tensor(422777060000.0, shape=(), dtype=float32)
# tf.Tensor(422774370000.0, shape=(), dtype=float32)
# tf.Tensor(422771650000.0, shape=(), dtype=float32)
# tf.Tensor(422768970000.0, shape=(), dtype=float32)
# tf.Tensor(422766250000.0, shape=(), dtype=float32)
# tf.Tensor(422763560000.0, shape=(), dtype=float32)
# tf.Tensor(422760800000.0, shape=(), dtype=float32)
# tf.Tensor(422758120000.0, shape=(), dtype=float32)
# tf.Tensor(422755400000.0, shape=(), dtype=float32)
# tf.Tensor(422752700000.0, shape=(), dtype=float32)
# tf.Tensor(422750030000.0, shape=(), dtype=float32)
# tf.Tensor(422747340000.0, shape=(), dtype=float32)
# tf.Tensor(422744620000.0, shape=(), dtype=float32)
# tf.Tensor(422742000000.0, shape=(), dtype=float32)
# tf.Tensor(422739200000.0, shape=(), dtype=float32)
# tf.Tensor(422736460000.0, shape=(), dtype=float32)
# tf.Tensor(422733740000.0, shape=(), dtype=float32)
# tf.Tensor(422731060000.0, shape=(), dtype=float32)
# tf.Tensor(422728370000.0, shape=(), dtype=float32)
# tf.Tensor(422725650000.0, shape=(), dtype=float32)
# tf.Tensor(422723000000.0, shape=(), dtype=float32)
# tf.Tensor(422720240000.0, shape=(), dtype=float32)
# tf.Tensor(422717550000.0, shape=(), dtype=float32)
# tf.Tensor(422714870000.0, shape=(), dtype=float32)
# tf.Tensor(422712180000.0, shape=(), dtype=float32)
# tf.Tensor(422709500000.0, shape=(), dtype=float32)
# tf.Tensor(422706700000.0, shape=(), dtype=float32)
# tf.Tensor(422704020000.0, shape=(), dtype=float32)
# tf.Tensor(422701300000.0, shape=(), dtype=float32)
# tf.Tensor(422698580000.0, shape=(), dtype=float32)
# tf.Tensor(422695900000.0, shape=(), dtype=float32)
# tf.Tensor(422693200000.0, shape=(), dtype=float32)
# tf.Tensor(422690520000.0, shape=(), dtype=float32)
# tf.Tensor(422687800000.0, shape=(), dtype=float32)
# tf.Tensor(422685100000.0, shape=(), dtype=float32)
# tf.Tensor(422682360000.0, shape=(), dtype=float32)
# tf.Tensor(422679670000.0, shape=(), dtype=float32)
# tf.Tensor(422676920000.0, shape=(), dtype=float32)
# tf.Tensor(422674270000.0, shape=(), dtype=float32)
# tf.Tensor(422671580000.0, shape=(), dtype=float32)
# tf.Tensor(422668860000.0, shape=(), dtype=float32)
# tf.Tensor(422666170000.0, shape=(), dtype=float32)
# tf.Tensor(422663450000.0, shape=(), dtype=float32)
# tf.Tensor(422660770000.0, shape=(), dtype=float32)
# tf.Tensor(422658000000.0, shape=(), dtype=float32)
# tf.Tensor(422655360000.0, shape=(), dtype=float32)
# tf.Tensor(422652600000.0, shape=(), dtype=float32)
# tf.Tensor(422649920000.0, shape=(), dtype=float32)
# tf.Tensor(422647200000.0, shape=(), dtype=float32)
# tf.Tensor(422644500000.0, shape=(), dtype=float32)
# tf.Tensor(422641830000.0, shape=(), dtype=float32)
# tf.Tensor(422639040000.0, shape=(), dtype=float32)
# tf.Tensor(422636420000.0, shape=(), dtype=float32)
# tf.Tensor(422633670000.0, shape=(), dtype=float32)
# tf.Tensor(422631000000.0, shape=(), dtype=float32)
# tf.Tensor(422628330000.0, shape=(), dtype=float32)
# tf.Tensor(422625540000.0, shape=(), dtype=float32)
# tf.Tensor(422622860000.0, shape=(), dtype=float32)
# tf.Tensor(422620170000.0, shape=(), dtype=float32)
# tf.Tensor(422617480000.0, shape=(), dtype=float32)
# tf.Tensor(422614800000.0, shape=(), dtype=float32)
# tf.Tensor(422612070000.0, shape=(), dtype=float32)
# tf.Tensor(422609400000.0, shape=(), dtype=float32)
# tf.Tensor(422606670000.0, shape=(), dtype=float32)
# tf.Tensor(422603900000.0, shape=(), dtype=float32)
# tf.Tensor(422601200000.0, shape=(), dtype=float32)
# tf.Tensor(422598500000.0, shape=(), dtype=float32)
# tf.Tensor(422595820000.0, shape=(), dtype=float32)
# tf.Tensor(422593130000.0, shape=(), dtype=float32)
# tf.Tensor(422590450000.0, shape=(), dtype=float32)
# tf.Tensor(422587700000.0, shape=(), dtype=float32)
# tf.Tensor(422585000000.0, shape=(), dtype=float32)
# tf.Tensor(422582260000.0, shape=(), dtype=float32)
# tf.Tensor(422579630000.0, shape=(), dtype=float32)
# tf.Tensor(422576850000.0, shape=(), dtype=float32)
# tf.Tensor(422574160000.0, shape=(), dtype=float32)
# tf.Tensor(422571470000.0, shape=(), dtype=float32)
# tf.Tensor(422568800000.0, shape=(), dtype=float32)
# tf.Tensor(422566070000.0, shape=(), dtype=float32)
# tf.Tensor(422563350000.0, shape=(), dtype=float32)
# tf.Tensor(422560700000.0, shape=(), dtype=float32)
# tf.Tensor(422557970000.0, shape=(), dtype=float32)
# tf.Tensor(422555300000.0, shape=(), dtype=float32)
# tf.Tensor(422552570000.0, shape=(), dtype=float32)
# tf.Tensor(422549800000.0, shape=(), dtype=float32)
# tf.Tensor(422547130000.0, shape=(), dtype=float32)
# tf.Tensor(422544400000.0, shape=(), dtype=float32)
# tf.Tensor(422541800000.0, shape=(), dtype=float32)
# tf.Tensor(422539000000.0, shape=(), dtype=float32)
# tf.Tensor(422536300000.0, shape=(), dtype=float32)
# tf.Tensor(422533560000.0, shape=(), dtype=float32)
# tf.Tensor(422530940000.0, shape=(), dtype=float32)
# tf.Tensor(422528220000.0, shape=(), dtype=float32)
# tf.Tensor(422525470000.0, shape=(), dtype=float32)
# tf.Tensor(422522780000.0, shape=(), dtype=float32)
# tf.Tensor(422520130000.0, shape=(), dtype=float32)
# tf.Tensor(422517370000.0, shape=(), dtype=float32)
# tf.Tensor(422514660000.0, shape=(), dtype=float32)
# tf.Tensor(422511970000.0, shape=(), dtype=float32)
# tf.Tensor(422509280000.0, shape=(), dtype=float32)
# tf.Tensor(422506500000.0, shape=(), dtype=float32)
# tf.Tensor(422503870000.0, shape=(), dtype=float32)
# tf.Tensor(422501120000.0, shape=(), dtype=float32)
# tf.Tensor(422498470000.0, shape=(), dtype=float32)
# tf.Tensor(422495780000.0, shape=(), dtype=float32)
# tf.Tensor(422493100000.0, shape=(), dtype=float32)
# tf.Tensor(422490400000.0, shape=(), dtype=float32)
# tf.Tensor(422487620000.0, shape=(), dtype=float32)
# tf.Tensor(422485000000.0, shape=(), dtype=float32)
# tf.Tensor(422482250000.0, shape=(), dtype=float32)
# tf.Tensor(422479530000.0, shape=(), dtype=float32)
# tf.Tensor(422476800000.0, shape=(), dtype=float32)
# tf.Tensor(422474120000.0, shape=(), dtype=float32)
# tf.Tensor(422471430000.0, shape=(), dtype=float32)
# tf.Tensor(422468680000.0, shape=(), dtype=float32)
# tf.Tensor(422465960000.0, shape=(), dtype=float32)
# tf.Tensor(422463280000.0, shape=(), dtype=float32)
# tf.Tensor(422460600000.0, shape=(), dtype=float32)
# tf.Tensor(422457870000.0, shape=(), dtype=float32)
# tf.Tensor(422455250000.0, shape=(), dtype=float32)
# tf.Tensor(422452500000.0, shape=(), dtype=float32)
# tf.Tensor(422449770000.0, shape=(), dtype=float32)
# tf.Tensor(422447100000.0, shape=(), dtype=float32)
# tf.Tensor(422444400000.0, shape=(), dtype=float32)
# tf.Tensor(422441680000.0, shape=(), dtype=float32)
# tf.Tensor(422438930000.0, shape=(), dtype=float32)
# tf.Tensor(422436300000.0, shape=(), dtype=float32)
# tf.Tensor(422433600000.0, shape=(), dtype=float32)
# tf.Tensor(422430900000.0, shape=(), dtype=float32)
# tf.Tensor(422428150000.0, shape=(), dtype=float32)
# tf.Tensor(422425430000.0, shape=(), dtype=float32)
# tf.Tensor(422422700000.0, shape=(), dtype=float32)
# tf.Tensor(422420050000.0, shape=(), dtype=float32)
# tf.Tensor(422417370000.0, shape=(), dtype=float32)
# tf.Tensor(422414580000.0, shape=(), dtype=float32)
# tf.Tensor(422411960000.0, shape=(), dtype=float32)
# tf.Tensor(422409240000.0, shape=(), dtype=float32)
# tf.Tensor(422406550000.0, shape=(), dtype=float32)
# tf.Tensor(422403800000.0, shape=(), dtype=float32)
# tf.Tensor(422401080000.0, shape=(), dtype=float32)
# tf.Tensor(422398400000.0, shape=(), dtype=float32)
# tf.Tensor(422395700000.0, shape=(), dtype=float32)
# tf.Tensor(422393020000.0, shape=(), dtype=float32)
# tf.Tensor(422390300000.0, shape=(), dtype=float32)
# tf.Tensor(422387600000.0, shape=(), dtype=float32)
# tf.Tensor(422384900000.0, shape=(), dtype=float32)
# tf.Tensor(422382200000.0, shape=(), dtype=float32)
# tf.Tensor(422379520000.0, shape=(), dtype=float32)
# tf.Tensor(422376800000.0, shape=(), dtype=float32)
# tf.Tensor(422374050000.0, shape=(), dtype=float32)
# tf.Tensor(422371360000.0, shape=(), dtype=float32)
# tf.Tensor(422368670000.0, shape=(), dtype=float32)
# tf.Tensor(422366020000.0, shape=(), dtype=float32)
# tf.Tensor(422363270000.0, shape=(), dtype=float32)
# tf.Tensor(422360550000.0, shape=(), dtype=float32)
# tf.Tensor(422357860000.0, shape=(), dtype=float32)
# tf.Tensor(422355170000.0, shape=(), dtype=float32)
# tf.Tensor(422352450000.0, shape=(), dtype=float32)
# tf.Tensor(422349700000.0, shape=(), dtype=float32)
# tf.Tensor(422347000000.0, shape=(), dtype=float32)
# tf.Tensor(422344360000.0, shape=(), dtype=float32)
# tf.Tensor(422341600000.0, shape=(), dtype=float32)
# tf.Tensor(422338920000.0, shape=(), dtype=float32)
# tf.Tensor(422336200000.0, shape=(), dtype=float32)
# tf.Tensor(422333500000.0, shape=(), dtype=float32)
# tf.Tensor(422330830000.0, shape=(), dtype=float32)
# tf.Tensor(422328100000.0, shape=(), dtype=float32)
# tf.Tensor(422325420000.0, shape=(), dtype=float32)
# tf.Tensor(422322700000.0, shape=(), dtype=float32)
# tf.Tensor(422320000000.0, shape=(), dtype=float32)
# tf.Tensor(422317330000.0, shape=(), dtype=float32)
# tf.Tensor(422314570000.0, shape=(), dtype=float32)
# tf.Tensor(422311850000.0, shape=(), dtype=float32)
# tf.Tensor(422309170000.0, shape=(), dtype=float32)
# tf.Tensor(422306480000.0, shape=(), dtype=float32)
# tf.Tensor(422303800000.0, shape=(), dtype=float32)
# tf.Tensor(422301140000.0, shape=(), dtype=float32)
# tf.Tensor(422298350000.0, shape=(), dtype=float32)
# tf.Tensor(422295670000.0, shape=(), dtype=float32)
# tf.Tensor(422292980000.0, shape=(), dtype=float32)
# tf.Tensor(422290300000.0, shape=(), dtype=float32)
# tf.Tensor(422287570000.0, shape=(), dtype=float32)
# tf.Tensor(422284820000.0, shape=(), dtype=float32)
# tf.Tensor(422282130000.0, shape=(), dtype=float32)
# tf.Tensor(422279480000.0, shape=(), dtype=float32)
# tf.Tensor(422276800000.0, shape=(), dtype=float32)
# tf.Tensor(422274000000.0, shape=(), dtype=float32)
# tf.Tensor(422271350000.0, shape=(), dtype=float32)
# tf.Tensor(422268630000.0, shape=(), dtype=float32)
# tf.Tensor(422265950000.0, shape=(), dtype=float32)
# tf.Tensor(422263260000.0, shape=(), dtype=float32)
# tf.Tensor(422260540000.0, shape=(), dtype=float32)
# tf.Tensor(422257800000.0, shape=(), dtype=float32)
# tf.Tensor(422255170000.0, shape=(), dtype=float32)
# tf.Tensor(422252450000.0, shape=(), dtype=float32)
# tf.Tensor(422249760000.0, shape=(), dtype=float32)
# tf.Tensor(422247000000.0, shape=(), dtype=float32)
# tf.Tensor(422244300000.0, shape=(), dtype=float32)
# tf.Tensor(422241600000.0, shape=(), dtype=float32)
# tf.Tensor(422238900000.0, shape=(), dtype=float32)
# tf.Tensor(422236230000.0, shape=(), dtype=float32)
# tf.Tensor(422233500000.0, shape=(), dtype=float32)
# tf.Tensor(422230800000.0, shape=(), dtype=float32)
# tf.Tensor(422228100000.0, shape=(), dtype=float32)
# tf.Tensor(422225400000.0, shape=(), dtype=float32)
# tf.Tensor(422222700000.0, shape=(), dtype=float32)
# tf.Tensor(422219940000.0, shape=(), dtype=float32)
# tf.Tensor(422217250000.0, shape=(), dtype=float32)
# tf.Tensor(422214570000.0, shape=(), dtype=float32)
# tf.Tensor(422211900000.0, shape=(), dtype=float32)
# tf.Tensor(422209130000.0, shape=(), dtype=float32)
# tf.Tensor(422206470000.0, shape=(), dtype=float32)
# tf.Tensor(422203750000.0, shape=(), dtype=float32)
# tf.Tensor(422201070000.0, shape=(), dtype=float32)
# tf.Tensor(422198380000.0, shape=(), dtype=float32)
# tf.Tensor(422195660000.0, shape=(), dtype=float32)
# tf.Tensor(422192900000.0, shape=(), dtype=float32)
# tf.Tensor(422190250000.0, shape=(), dtype=float32)
# tf.Tensor(422187570000.0, shape=(), dtype=float32)
# tf.Tensor(422184880000.0, shape=(), dtype=float32)
# tf.Tensor(422182130000.0, shape=(), dtype=float32)
# tf.Tensor(422179400000.0, shape=(), dtype=float32)
# tf.Tensor(422176800000.0, shape=(), dtype=float32)
# tf.Tensor(422174030000.0, shape=(), dtype=float32)
# tf.Tensor(422171340000.0, shape=(), dtype=float32)
# tf.Tensor(422168700000.0, shape=(), dtype=float32)
# tf.Tensor(422165900000.0, shape=(), dtype=float32)
# tf.Tensor(422163220000.0, shape=(), dtype=float32)
# tf.Tensor(422160530000.0, shape=(), dtype=float32)
# tf.Tensor(422157840000.0, shape=(), dtype=float32)
# tf.Tensor(422155160000.0, shape=(), dtype=float32)
# tf.Tensor(422152470000.0, shape=(), dtype=float32)
# tf.Tensor(422149700000.0, shape=(), dtype=float32)
# tf.Tensor(422147030000.0, shape=(), dtype=float32)
# tf.Tensor(422144340000.0, shape=(), dtype=float32)
# tf.Tensor(422141560000.0, shape=(), dtype=float32)
# tf.Tensor(422138900000.0, shape=(), dtype=float32)
# tf.Tensor(422136200000.0, shape=(), dtype=float32)
# tf.Tensor(422133500000.0, shape=(), dtype=float32)
# tf.Tensor(422130800000.0, shape=(), dtype=float32)
# tf.Tensor(422128100000.0, shape=(), dtype=float32)
# tf.Tensor(422125370000.0, shape=(), dtype=float32)
# tf.Tensor(422122720000.0, shape=(), dtype=float32)
# tf.Tensor(422120000000.0, shape=(), dtype=float32)
# tf.Tensor(422117300000.0, shape=(), dtype=float32)
# tf.Tensor(422114620000.0, shape=(), dtype=float32)
# tf.Tensor(422111940000.0, shape=(), dtype=float32)
# tf.Tensor(422109150000.0, shape=(), dtype=float32)
# tf.Tensor(422106460000.0, shape=(), dtype=float32)
# tf.Tensor(422103800000.0, shape=(), dtype=float32)
# tf.Tensor(422101120000.0, shape=(), dtype=float32)
# tf.Tensor(422098370000.0, shape=(), dtype=float32)
# tf.Tensor(422095650000.0, shape=(), dtype=float32)
# tf.Tensor(422092960000.0, shape=(), dtype=float32)
# tf.Tensor(422090280000.0, shape=(), dtype=float32)
# tf.Tensor(422087600000.0, shape=(), dtype=float32)
# tf.Tensor(422084900000.0, shape=(), dtype=float32)
# tf.Tensor(422082180000.0, shape=(), dtype=float32)
# tf.Tensor(422079500000.0, shape=(), dtype=float32)
# tf.Tensor(422076780000.0, shape=(), dtype=float32)
# tf.Tensor(422074100000.0, shape=(), dtype=float32)
# tf.Tensor(422071340000.0, shape=(), dtype=float32)
# tf.Tensor(422068620000.0, shape=(), dtype=float32)
# tf.Tensor(422065930000.0, shape=(), dtype=float32)
# tf.Tensor(422063240000.0, shape=(), dtype=float32)
# tf.Tensor(422060560000.0, shape=(), dtype=float32)
# tf.Tensor(422057800000.0, shape=(), dtype=float32)
# tf.Tensor(422055150000.0, shape=(), dtype=float32)
# tf.Tensor(422052430000.0, shape=(), dtype=float32)
# tf.Tensor(422049740000.0, shape=(), dtype=float32)
# tf.Tensor(422047020000.0, shape=(), dtype=float32)
# tf.Tensor(422044340000.0, shape=(), dtype=float32)
# tf.Tensor(422041650000.0, shape=(), dtype=float32)
# tf.Tensor(422038900000.0, shape=(), dtype=float32)
# tf.Tensor(422036240000.0, shape=(), dtype=float32)
# tf.Tensor(422033560000.0, shape=(), dtype=float32)
# tf.Tensor(422030800000.0, shape=(), dtype=float32)
# tf.Tensor(422028080000.0, shape=(), dtype=float32)
# tf.Tensor(422025400000.0, shape=(), dtype=float32)
# tf.Tensor(422022700000.0, shape=(), dtype=float32)
# tf.Tensor(422020020000.0, shape=(), dtype=float32)
# tf.Tensor(422017340000.0, shape=(), dtype=float32)
# tf.Tensor(422014600000.0, shape=(), dtype=float32)
# tf.Tensor(422012000000.0, shape=(), dtype=float32)
# tf.Tensor(422009240000.0, shape=(), dtype=float32)
# tf.Tensor(422006520000.0, shape=(), dtype=float32)
# tf.Tensor(422003830000.0, shape=(), dtype=float32)
# tf.Tensor(422001100000.0, shape=(), dtype=float32)
# tf.Tensor(421998430000.0, shape=(), dtype=float32)
# tf.Tensor(421995680000.0, shape=(), dtype=float32)
# tf.Tensor(421993020000.0, shape=(), dtype=float32)
# tf.Tensor(421990330000.0, shape=(), dtype=float32)
# tf.Tensor(421987580000.0, shape=(), dtype=float32)
# tf.Tensor(421984900000.0, shape=(), dtype=float32)
# tf.Tensor(421982240000.0, shape=(), dtype=float32)
# tf.Tensor(421979500000.0, shape=(), dtype=float32)
# tf.Tensor(421976800000.0, shape=(), dtype=float32)
# tf.Tensor(421974100000.0, shape=(), dtype=float32)
# tf.Tensor(421971460000.0, shape=(), dtype=float32)
# tf.Tensor(421968700000.0, shape=(), dtype=float32)
# tf.Tensor(421966020000.0, shape=(), dtype=float32)
# tf.Tensor(421963300000.0, shape=(), dtype=float32)
# tf.Tensor(421960600000.0, shape=(), dtype=float32)
# tf.Tensor(421957900000.0, shape=(), dtype=float32)
# tf.Tensor(421955200000.0, shape=(), dtype=float32)
# tf.Tensor(421952450000.0, shape=(), dtype=float32)
# tf.Tensor(421949800000.0, shape=(), dtype=float32)
# tf.Tensor(421947100000.0, shape=(), dtype=float32)
# tf.Tensor(421944360000.0, shape=(), dtype=float32)
# tf.Tensor(421941640000.0, shape=(), dtype=float32)
# tf.Tensor(421938950000.0, shape=(), dtype=float32)
# tf.Tensor(421936270000.0, shape=(), dtype=float32)
# tf.Tensor(421933580000.0, shape=(), dtype=float32)
# tf.Tensor(421930900000.0, shape=(), dtype=float32)
# tf.Tensor(421928170000.0, shape=(), dtype=float32)
# tf.Tensor(421925450000.0, shape=(), dtype=float32)
# tf.Tensor(421922800000.0, shape=(), dtype=float32)
# tf.Tensor(421920000000.0, shape=(), dtype=float32)
# tf.Tensor(421917400000.0, shape=(), dtype=float32)
# tf.Tensor(421914670000.0, shape=(), dtype=float32)
# tf.Tensor(421911920000.0, shape=(), dtype=float32)
# tf.Tensor(421909230000.0, shape=(), dtype=float32)
# tf.Tensor(421906550000.0, shape=(), dtype=float32)
# tf.Tensor(421903900000.0, shape=(), dtype=float32)
# tf.Tensor(421901140000.0, shape=(), dtype=float32)
# tf.Tensor(421898450000.0, shape=(), dtype=float32)
# tf.Tensor(421895730000.0, shape=(), dtype=float32)
# tf.Tensor(421893050000.0, shape=(), dtype=float32)
# tf.Tensor(421890360000.0, shape=(), dtype=float32)
# tf.Tensor(421887670000.0, shape=(), dtype=float32)
# tf.Tensor(421884950000.0, shape=(), dtype=float32)
# tf.Tensor(421882270000.0, shape=(), dtype=float32)
# tf.Tensor(421879550000.0, shape=(), dtype=float32)
# tf.Tensor(421876860000.0, shape=(), dtype=float32)
# tf.Tensor(421874170000.0, shape=(), dtype=float32)
# tf.Tensor(421871450000.0, shape=(), dtype=float32)
# tf.Tensor(421868800000.0, shape=(), dtype=float32)
# tf.Tensor(421866000000.0, shape=(), dtype=float32)
# tf.Tensor(421863330000.0, shape=(), dtype=float32)
# tf.Tensor(421860670000.0, shape=(), dtype=float32)
# tf.Tensor(421857920000.0, shape=(), dtype=float32)
# tf.Tensor(421855200000.0, shape=(), dtype=float32)
# tf.Tensor(421852500000.0, shape=(), dtype=float32)
# tf.Tensor(421849830000.0, shape=(), dtype=float32)
# tf.Tensor(421847140000.0, shape=(), dtype=float32)
# tf.Tensor(421844450000.0, shape=(), dtype=float32)
# tf.Tensor(421841760000.0, shape=(), dtype=float32)
# tf.Tensor(421839100000.0, shape=(), dtype=float32)
# tf.Tensor(421836320000.0, shape=(), dtype=float32)
# tf.Tensor(421833640000.0, shape=(), dtype=float32)
# tf.Tensor(421830950000.0, shape=(), dtype=float32)
# tf.Tensor(421828260000.0, shape=(), dtype=float32)
# tf.Tensor(421825480000.0, shape=(), dtype=float32)
# tf.Tensor(421822860000.0, shape=(), dtype=float32)
# tf.Tensor(421820100000.0, shape=(), dtype=float32)
# tf.Tensor(421817450000.0, shape=(), dtype=float32)
# tf.Tensor(421814760000.0, shape=(), dtype=float32)
# tf.Tensor(421812080000.0, shape=(), dtype=float32)
# tf.Tensor(421809400000.0, shape=(), dtype=float32)
# tf.Tensor(421806670000.0, shape=(), dtype=float32)
# tf.Tensor(421803920000.0, shape=(), dtype=float32)
# tf.Tensor(421801230000.0, shape=(), dtype=float32)
# tf.Tensor(421798500000.0, shape=(), dtype=float32)
# tf.Tensor(421795820000.0, shape=(), dtype=float32)
# tf.Tensor(421793140000.0, shape=(), dtype=float32)
# tf.Tensor(421790420000.0, shape=(), dtype=float32)
# tf.Tensor(421787730000.0, shape=(), dtype=float32)
# tf.Tensor(421785040000.0, shape=(), dtype=float32)
# tf.Tensor(421782320000.0, shape=(), dtype=float32)
# tf.Tensor(421779640000.0, shape=(), dtype=float32)
# tf.Tensor(421776900000.0, shape=(), dtype=float32)
# tf.Tensor(421774230000.0, shape=(), dtype=float32)
# tf.Tensor(421771540000.0, shape=(), dtype=float32)
# tf.Tensor(421768800000.0, shape=(), dtype=float32)
# tf.Tensor(421766100000.0, shape=(), dtype=float32)
# tf.Tensor(421763450000.0, shape=(), dtype=float32)
# tf.Tensor(421760700000.0, shape=(), dtype=float32)
# tf.Tensor(421758000000.0, shape=(), dtype=float32)
# tf.Tensor(421755300000.0, shape=(), dtype=float32)
# tf.Tensor(421752670000.0, shape=(), dtype=float32)
# tf.Tensor(421749900000.0, shape=(), dtype=float32)
# tf.Tensor(421747200000.0, shape=(), dtype=float32)
# tf.Tensor(421744500000.0, shape=(), dtype=float32)
# tf.Tensor(421741820000.0, shape=(), dtype=float32)
# tf.Tensor(421739130000.0, shape=(), dtype=float32)
# tf.Tensor(421736400000.0, shape=(), dtype=float32)
# tf.Tensor(421733660000.0, shape=(), dtype=float32)
# tf.Tensor(421731040000.0, shape=(), dtype=float32)
# tf.Tensor(421728320000.0, shape=(), dtype=float32)
# tf.Tensor(421725630000.0, shape=(), dtype=float32)
# tf.Tensor(421722950000.0, shape=(), dtype=float32)
# tf.Tensor(421720230000.0, shape=(), dtype=float32)
# tf.Tensor(421717480000.0, shape=(), dtype=float32)
# tf.Tensor(421714850000.0, shape=(), dtype=float32)
# tf.Tensor(421712100000.0, shape=(), dtype=float32)
# tf.Tensor(421709380000.0, shape=(), dtype=float32)
# tf.Tensor(421706760000.0, shape=(), dtype=float32)
# tf.Tensor(421704000000.0, shape=(), dtype=float32)
# tf.Tensor(421701300000.0, shape=(), dtype=float32)
# tf.Tensor(421698600000.0, shape=(), dtype=float32)
# tf.Tensor(421695900000.0, shape=(), dtype=float32)
# tf.Tensor(421693200000.0, shape=(), dtype=float32)
# tf.Tensor(421690540000.0, shape=(), dtype=float32)
# tf.Tensor(421687820000.0, shape=(), dtype=float32)
# tf.Tensor(421685200000.0, shape=(), dtype=float32)
# tf.Tensor(421682450000.0, shape=(), dtype=float32)
# tf.Tensor(421679730000.0, shape=(), dtype=float32)
# tf.Tensor(421676970000.0, shape=(), dtype=float32)
# tf.Tensor(421674320000.0, shape=(), dtype=float32)
# tf.Tensor(421671670000.0, shape=(), dtype=float32)
# tf.Tensor(421668880000.0, shape=(), dtype=float32)
# tf.Tensor(421666200000.0, shape=(), dtype=float32)
# tf.Tensor(421663540000.0, shape=(), dtype=float32)
# tf.Tensor(421660750000.0, shape=(), dtype=float32)
# tf.Tensor(421658170000.0, shape=(), dtype=float32)
# tf.Tensor(421655480000.0, shape=(), dtype=float32)
# tf.Tensor(421652700000.0, shape=(), dtype=float32)
# tf.Tensor(421650000000.0, shape=(), dtype=float32)
# tf.Tensor(421647320000.0, shape=(), dtype=float32)
# tf.Tensor(421644600000.0, shape=(), dtype=float32)
# tf.Tensor(421641900000.0, shape=(), dtype=float32)
# tf.Tensor(421639200000.0, shape=(), dtype=float32)
# tf.Tensor(421636500000.0, shape=(), dtype=float32)
# tf.Tensor(421633820000.0, shape=(), dtype=float32)
# tf.Tensor(421631130000.0, shape=(), dtype=float32)
# tf.Tensor(421628440000.0, shape=(), dtype=float32)
# tf.Tensor(421625720000.0, shape=(), dtype=float32)
# tf.Tensor(421623040000.0, shape=(), dtype=float32)
# tf.Tensor(421620320000.0, shape=(), dtype=float32)
# tf.Tensor(421617630000.0, shape=(), dtype=float32)
# tf.Tensor(421614940000.0, shape=(), dtype=float32)
# tf.Tensor(421612260000.0, shape=(), dtype=float32)
# tf.Tensor(421609540000.0, shape=(), dtype=float32)
# tf.Tensor(421606800000.0, shape=(), dtype=float32)
# tf.Tensor(421604100000.0, shape=(), dtype=float32)
# tf.Tensor(421601400000.0, shape=(), dtype=float32)
# tf.Tensor(421598760000.0, shape=(), dtype=float32)
# tf.Tensor(421596070000.0, shape=(), dtype=float32)
# tf.Tensor(421593380000.0, shape=(), dtype=float32)
# tf.Tensor(421590630000.0, shape=(), dtype=float32)
# tf.Tensor(421587980000.0, shape=(), dtype=float32)
# tf.Tensor(421585220000.0, shape=(), dtype=float32)
# tf.Tensor(421582540000.0, shape=(), dtype=float32)
# tf.Tensor(421579850000.0, shape=(), dtype=float32)
# tf.Tensor(421577130000.0, shape=(), dtype=float32)
# tf.Tensor(421574500000.0, shape=(), dtype=float32)
# tf.Tensor(421571720000.0, shape=(), dtype=float32)
# tf.Tensor(421569040000.0, shape=(), dtype=float32)
# tf.Tensor(421566350000.0, shape=(), dtype=float32)
# tf.Tensor(421563660000.0, shape=(), dtype=float32)
# tf.Tensor(421560940000.0, shape=(), dtype=float32)
# tf.Tensor(421558200000.0, shape=(), dtype=float32)
# tf.Tensor(421555540000.0, shape=(), dtype=float32)
# tf.Tensor(421552850000.0, shape=(), dtype=float32)
# tf.Tensor(421550160000.0, shape=(), dtype=float32)
# tf.Tensor(421547470000.0, shape=(), dtype=float32)
# tf.Tensor(421544760000.0, shape=(), dtype=float32)
# tf.Tensor(421542000000.0, shape=(), dtype=float32)
# tf.Tensor(421539380000.0, shape=(), dtype=float32)
# tf.Tensor(421536630000.0, shape=(), dtype=float32)
# tf.Tensor(421533900000.0, shape=(), dtype=float32)
# tf.Tensor(421531300000.0, shape=(), dtype=float32)
# tf.Tensor(421528540000.0, shape=(), dtype=float32)
# tf.Tensor(421525850000.0, shape=(), dtype=float32)
# tf.Tensor(421523130000.0, shape=(), dtype=float32)
# tf.Tensor(421520440000.0, shape=(), dtype=float32)
# tf.Tensor(421517750000.0, shape=(), dtype=float32)
# tf.Tensor(421515030000.0, shape=(), dtype=float32)
# tf.Tensor(421512400000.0, shape=(), dtype=float32)
# tf.Tensor(421509630000.0, shape=(), dtype=float32)
# tf.Tensor(421506940000.0, shape=(), dtype=float32)
# tf.Tensor(421504250000.0, shape=(), dtype=float32)
# tf.Tensor(421501570000.0, shape=(), dtype=float32)
# tf.Tensor(421498880000.0, shape=(), dtype=float32)
# tf.Tensor(421496160000.0, shape=(), dtype=float32)
# tf.Tensor(421493470000.0, shape=(), dtype=float32)
# tf.Tensor(421490800000.0, shape=(), dtype=float32)
# tf.Tensor(421488070000.0, shape=(), dtype=float32)
# tf.Tensor(421485380000.0, shape=(), dtype=float32)
# tf.Tensor(421482700000.0, shape=(), dtype=float32)
# tf.Tensor(421479970000.0, shape=(), dtype=float32)
# tf.Tensor(421477320000.0, shape=(), dtype=float32)
# tf.Tensor(421474530000.0, shape=(), dtype=float32)
# tf.Tensor(421471850000.0, shape=(), dtype=float32)
# tf.Tensor(421469200000.0, shape=(), dtype=float32)
# tf.Tensor(421466440000.0, shape=(), dtype=float32)
# tf.Tensor(421463750000.0, shape=(), dtype=float32)
# tf.Tensor(421461030000.0, shape=(), dtype=float32)
# tf.Tensor(421458350000.0, shape=(), dtype=float32)
# tf.Tensor(421455660000.0, shape=(), dtype=float32)
# tf.Tensor(421453040000.0, shape=(), dtype=float32)
# tf.Tensor(421450300000.0, shape=(), dtype=float32)
# tf.Tensor(421447630000.0, shape=(), dtype=float32)
# tf.Tensor(421444850000.0, shape=(), dtype=float32)
# tf.Tensor(421442160000.0, shape=(), dtype=float32)
# tf.Tensor(421439470000.0, shape=(), dtype=float32)
# tf.Tensor(421436850000.0, shape=(), dtype=float32)
# tf.Tensor(421434100000.0, shape=(), dtype=float32)
# tf.Tensor(421431400000.0, shape=(), dtype=float32)
# tf.Tensor(421428700000.0, shape=(), dtype=float32)
# tf.Tensor(421426000000.0, shape=(), dtype=float32)
# tf.Tensor(421423300000.0, shape=(), dtype=float32)
# tf.Tensor(421420600000.0, shape=(), dtype=float32)
# tf.Tensor(421417900000.0, shape=(), dtype=float32)
# tf.Tensor(421415220000.0, shape=(), dtype=float32)
# tf.Tensor(421412500000.0, shape=(), dtype=float32)
# tf.Tensor(421409850000.0, shape=(), dtype=float32)
# tf.Tensor(421407060000.0, shape=(), dtype=float32)
# tf.Tensor(421404400000.0, shape=(), dtype=float32)
# tf.Tensor(421401720000.0, shape=(), dtype=float32)
# tf.Tensor(421399040000.0, shape=(), dtype=float32)
# tf.Tensor(421396350000.0, shape=(), dtype=float32)
# tf.Tensor(421393630000.0, shape=(), dtype=float32)
# tf.Tensor(421390940000.0, shape=(), dtype=float32)
# tf.Tensor(421388200000.0, shape=(), dtype=float32)
# tf.Tensor(421385470000.0, shape=(), dtype=float32)
# tf.Tensor(421382850000.0, shape=(), dtype=float32)
# tf.Tensor(421380160000.0, shape=(), dtype=float32)
# tf.Tensor(421377400000.0, shape=(), dtype=float32)
# tf.Tensor(421374720000.0, shape=(), dtype=float32)
# tf.Tensor(421372000000.0, shape=(), dtype=float32)
# tf.Tensor(421369300000.0, shape=(), dtype=float32)
# tf.Tensor(421366630000.0, shape=(), dtype=float32)
# tf.Tensor(421363940000.0, shape=(), dtype=float32)
# tf.Tensor(421361300000.0, shape=(), dtype=float32)
# tf.Tensor(421358530000.0, shape=(), dtype=float32)
# tf.Tensor(421355800000.0, shape=(), dtype=float32)
# tf.Tensor(421353130000.0, shape=(), dtype=float32)
# tf.Tensor(421350440000.0, shape=(), dtype=float32)
# tf.Tensor(421347750000.0, shape=(), dtype=float32)
# tf.Tensor(421345070000.0, shape=(), dtype=float32)
# tf.Tensor(421342380000.0, shape=(), dtype=float32)
# tf.Tensor(421339660000.0, shape=(), dtype=float32)
# tf.Tensor(421336970000.0, shape=(), dtype=float32)
# tf.Tensor(421334250000.0, shape=(), dtype=float32)
# tf.Tensor(421331500000.0, shape=(), dtype=float32)
# tf.Tensor(421328880000.0, shape=(), dtype=float32)
# tf.Tensor(421326160000.0, shape=(), dtype=float32)
# tf.Tensor(421323500000.0, shape=(), dtype=float32)
# tf.Tensor(421320720000.0, shape=(), dtype=float32)
# tf.Tensor(421318030000.0, shape=(), dtype=float32)
# tf.Tensor(421315380000.0, shape=(), dtype=float32)
# tf.Tensor(421312700000.0, shape=(), dtype=float32)
# tf.Tensor(421310000000.0, shape=(), dtype=float32)
# tf.Tensor(421307320000.0, shape=(), dtype=float32)
# tf.Tensor(421304600000.0, shape=(), dtype=float32)
# tf.Tensor(421301900000.0, shape=(), dtype=float32)
# tf.Tensor(421299160000.0, shape=(), dtype=float32)
# tf.Tensor(421296470000.0, shape=(), dtype=float32)
# tf.Tensor(421293820000.0, shape=(), dtype=float32)
# tf.Tensor(421291130000.0, shape=(), dtype=float32)
# tf.Tensor(421288440000.0, shape=(), dtype=float32)
# tf.Tensor(421285660000.0, shape=(), dtype=float32)
# tf.Tensor(421282970000.0, shape=(), dtype=float32)
# tf.Tensor(421280300000.0, shape=(), dtype=float32)
# tf.Tensor(421277600000.0, shape=(), dtype=float32)
# tf.Tensor(421274900000.0, shape=(), dtype=float32)
# tf.Tensor(421272260000.0, shape=(), dtype=float32)
# tf.Tensor(421269470000.0, shape=(), dtype=float32)
# tf.Tensor(421266820000.0, shape=(), dtype=float32)
# tf.Tensor(421264100000.0, shape=(), dtype=float32)
# tf.Tensor(421261400000.0, shape=(), dtype=float32)
# tf.Tensor(421258720000.0, shape=(), dtype=float32)
# tf.Tensor(421256000000.0, shape=(), dtype=float32)
# tf.Tensor(421253320000.0, shape=(), dtype=float32)
# tf.Tensor(421250630000.0, shape=(), dtype=float32)
# tf.Tensor(421247900000.0, shape=(), dtype=float32)
# tf.Tensor(421245220000.0, shape=(), dtype=float32)
# tf.Tensor(421242540000.0, shape=(), dtype=float32)
# tf.Tensor(421239850000.0, shape=(), dtype=float32)
# tf.Tensor(421237130000.0, shape=(), dtype=float32)
# tf.Tensor(421234440000.0, shape=(), dtype=float32)
# tf.Tensor(421231700000.0, shape=(), dtype=float32)
# tf.Tensor(421229040000.0, shape=(), dtype=float32)
# tf.Tensor(421226350000.0, shape=(), dtype=float32)
# tf.Tensor(421223660000.0, shape=(), dtype=float32)
# tf.Tensor(421220970000.0, shape=(), dtype=float32)
# tf.Tensor(421218250000.0, shape=(), dtype=float32)
# tf.Tensor(421215570000.0, shape=(), dtype=float32)
# tf.Tensor(421212800000.0, shape=(), dtype=float32)
# tf.Tensor(421210130000.0, shape=(), dtype=float32)
# tf.Tensor(421207470000.0, shape=(), dtype=float32)
# tf.Tensor(421204800000.0, shape=(), dtype=float32)
# tf.Tensor(421202030000.0, shape=(), dtype=float32)
# tf.Tensor(421199350000.0, shape=(), dtype=float32)
# tf.Tensor(421196700000.0, shape=(), dtype=float32)
# tf.Tensor(421194000000.0, shape=(), dtype=float32)
# tf.Tensor(421191250000.0, shape=(), dtype=float32)
# tf.Tensor(421188570000.0, shape=(), dtype=float32)
# tf.Tensor(421185900000.0, shape=(), dtype=float32)
# tf.Tensor(421183160000.0, shape=(), dtype=float32)
# tf.Tensor(421180440000.0, shape=(), dtype=float32)
# tf.Tensor(421177750000.0, shape=(), dtype=float32)
# tf.Tensor(421175130000.0, shape=(), dtype=float32)
# tf.Tensor(421172380000.0, shape=(), dtype=float32)
# tf.Tensor(421169700000.0, shape=(), dtype=float32)
# tf.Tensor(421167000000.0, shape=(), dtype=float32)
# tf.Tensor(421164350000.0, shape=(), dtype=float32)
# tf.Tensor(421161600000.0, shape=(), dtype=float32)
# tf.Tensor(421158880000.0, shape=(), dtype=float32)
# tf.Tensor(421156200000.0, shape=(), dtype=float32)
# tf.Tensor(421153500000.0, shape=(), dtype=float32)
# tf.Tensor(421150820000.0, shape=(), dtype=float32)
# tf.Tensor(421148130000.0, shape=(), dtype=float32)
# tf.Tensor(421145440000.0, shape=(), dtype=float32)
# tf.Tensor(421142720000.0, shape=(), dtype=float32)
# tf.Tensor(421140040000.0, shape=(), dtype=float32)
# tf.Tensor(421137320000.0, shape=(), dtype=float32)
# tf.Tensor(421134660000.0, shape=(), dtype=float32)
# tf.Tensor(421131940000.0, shape=(), dtype=float32)
# tf.Tensor(421129260000.0, shape=(), dtype=float32)
# tf.Tensor(421126570000.0, shape=(), dtype=float32)
# tf.Tensor(421123850000.0, shape=(), dtype=float32)
# tf.Tensor(421121160000.0, shape=(), dtype=float32)
# tf.Tensor(421118440000.0, shape=(), dtype=float32)
# tf.Tensor(421115760000.0, shape=(), dtype=float32)
# tf.Tensor(421113070000.0, shape=(), dtype=float32)
# tf.Tensor(421110350000.0, shape=(), dtype=float32)
# tf.Tensor(421107660000.0, shape=(), dtype=float32)
# tf.Tensor(421105000000.0, shape=(), dtype=float32)
# tf.Tensor(421102220000.0, shape=(), dtype=float32)
# tf.Tensor(421099600000.0, shape=(), dtype=float32)
# tf.Tensor(421096880000.0, shape=(), dtype=float32)
# tf.Tensor(421094200000.0, shape=(), dtype=float32)
# tf.Tensor(421091500000.0, shape=(), dtype=float32)
# tf.Tensor(421088800000.0, shape=(), dtype=float32)
# tf.Tensor(421086100000.0, shape=(), dtype=float32)
# tf.Tensor(421083400000.0, shape=(), dtype=float32)
# tf.Tensor(421080660000.0, shape=(), dtype=float32)
# tf.Tensor(421078000000.0, shape=(), dtype=float32)
# tf.Tensor(421075320000.0, shape=(), dtype=float32)
# tf.Tensor(421072630000.0, shape=(), dtype=float32)
# tf.Tensor(421069880000.0, shape=(), dtype=float32)
# tf.Tensor(421067230000.0, shape=(), dtype=float32)
# tf.Tensor(421064540000.0, shape=(), dtype=float32)
# tf.Tensor(421061800000.0, shape=(), dtype=float32)
# tf.Tensor(421059070000.0, shape=(), dtype=float32)
# tf.Tensor(421056450000.0, shape=(), dtype=float32)
# tf.Tensor(421053760000.0, shape=(), dtype=float32)
# tf.Tensor(421051000000.0, shape=(), dtype=float32)
# tf.Tensor(421048320000.0, shape=(), dtype=float32)
# tf.Tensor(421045600000.0, shape=(), dtype=float32)
# tf.Tensor(421042980000.0, shape=(), dtype=float32)
# tf.Tensor(421040230000.0, shape=(), dtype=float32)
# tf.Tensor(421037540000.0, shape=(), dtype=float32)
# tf.Tensor(421034900000.0, shape=(), dtype=float32)
# tf.Tensor(421032200000.0, shape=(), dtype=float32)
# tf.Tensor(421029500000.0, shape=(), dtype=float32)
# tf.Tensor(421026760000.0, shape=(), dtype=float32)
# tf.Tensor(421024040000.0, shape=(), dtype=float32)
# tf.Tensor(421021350000.0, shape=(), dtype=float32)
# tf.Tensor(421018660000.0, shape=(), dtype=float32)
# tf.Tensor(421015980000.0, shape=(), dtype=float32)
# tf.Tensor(421013320000.0, shape=(), dtype=float32)
# tf.Tensor(421010640000.0, shape=(), dtype=float32)
# tf.Tensor(421007950000.0, shape=(), dtype=float32)
# tf.Tensor(421005200000.0, shape=(), dtype=float32)
# tf.Tensor(421002540000.0, shape=(), dtype=float32)
# tf.Tensor(420999800000.0, shape=(), dtype=float32)
# tf.Tensor(420997100000.0, shape=(), dtype=float32)
# tf.Tensor(420994400000.0, shape=(), dtype=float32)
# tf.Tensor(420991760000.0, shape=(), dtype=float32)
# tf.Tensor(420988980000.0, shape=(), dtype=float32)
# tf.Tensor(420986320000.0, shape=(), dtype=float32)
# tf.Tensor(420983600000.0, shape=(), dtype=float32)
# tf.Tensor(420980900000.0, shape=(), dtype=float32)
# tf.Tensor(420978230000.0, shape=(), dtype=float32)
# tf.Tensor(420975540000.0, shape=(), dtype=float32)
# tf.Tensor(420972820000.0, shape=(), dtype=float32)
# tf.Tensor(420970200000.0, shape=(), dtype=float32)
# tf.Tensor(420967450000.0, shape=(), dtype=float32)
# tf.Tensor(420964760000.0, shape=(), dtype=float32)
# tf.Tensor(420962070000.0, shape=(), dtype=float32)
# tf.Tensor(420959350000.0, shape=(), dtype=float32)
# tf.Tensor(420956670000.0, shape=(), dtype=float32)
# tf.Tensor(420953950000.0, shape=(), dtype=float32)
# tf.Tensor(420951300000.0, shape=(), dtype=float32)
# tf.Tensor(420948640000.0, shape=(), dtype=float32)
# tf.Tensor(420945900000.0, shape=(), dtype=float32)
# tf.Tensor(420943200000.0, shape=(), dtype=float32)
# tf.Tensor(420940500000.0, shape=(), dtype=float32)
# tf.Tensor(420937800000.0, shape=(), dtype=float32)
# tf.Tensor(420935100000.0, shape=(), dtype=float32)
# tf.Tensor(420932400000.0, shape=(), dtype=float32)
# tf.Tensor(420929700000.0, shape=(), dtype=float32)
# tf.Tensor(420927000000.0, shape=(), dtype=float32)
# tf.Tensor(420924300000.0, shape=(), dtype=float32)
# tf.Tensor(420921600000.0, shape=(), dtype=float32)
# tf.Tensor(420918920000.0, shape=(), dtype=float32)
# tf.Tensor(420916230000.0, shape=(), dtype=float32)
# tf.Tensor(420913550000.0, shape=(), dtype=float32)
# tf.Tensor(420910860000.0, shape=(), dtype=float32)
# tf.Tensor(420908140000.0, shape=(), dtype=float32)
# tf.Tensor(420905450000.0, shape=(), dtype=float32)
# tf.Tensor(420902760000.0, shape=(), dtype=float32)
# tf.Tensor(420900040000.0, shape=(), dtype=float32)
# tf.Tensor(420897360000.0, shape=(), dtype=float32)
# tf.Tensor(420894670000.0, shape=(), dtype=float32)
# tf.Tensor(420891950000.0, shape=(), dtype=float32)
# tf.Tensor(420889260000.0, shape=(), dtype=float32)
# tf.Tensor(420886580000.0, shape=(), dtype=float32)
# tf.Tensor(420883860000.0, shape=(), dtype=float32)
# tf.Tensor(420881170000.0, shape=(), dtype=float32)
# tf.Tensor(420878480000.0, shape=(), dtype=float32)
# tf.Tensor(420875800000.0, shape=(), dtype=float32)
# tf.Tensor(420873100000.0, shape=(), dtype=float32)
# tf.Tensor(420870420000.0, shape=(), dtype=float32)
# tf.Tensor(420867700000.0, shape=(), dtype=float32)
# tf.Tensor(420865050000.0, shape=(), dtype=float32)
# tf.Tensor(420862330000.0, shape=(), dtype=float32)
# tf.Tensor(420859600000.0, shape=(), dtype=float32)
# tf.Tensor(420856920000.0, shape=(), dtype=float32)
# tf.Tensor(420854240000.0, shape=(), dtype=float32)
# tf.Tensor(420851550000.0, shape=(), dtype=float32)
# tf.Tensor(420848830000.0, shape=(), dtype=float32)
# tf.Tensor(420846140000.0, shape=(), dtype=float32)
# tf.Tensor(420843400000.0, shape=(), dtype=float32)
# tf.Tensor(420840830000.0, shape=(), dtype=float32)
# tf.Tensor(420838050000.0, shape=(), dtype=float32)
# tf.Tensor(420835300000.0, shape=(), dtype=float32)
# tf.Tensor(420832670000.0, shape=(), dtype=float32)
# tf.Tensor(420829950000.0, shape=(), dtype=float32)
# tf.Tensor(420827300000.0, shape=(), dtype=float32)
# tf.Tensor(420824600000.0, shape=(), dtype=float32)
# tf.Tensor(420821900000.0, shape=(), dtype=float32)
# tf.Tensor(420819170000.0, shape=(), dtype=float32)
# tf.Tensor(420816500000.0, shape=(), dtype=float32)
# tf.Tensor(420813800000.0, shape=(), dtype=float32)
# tf.Tensor(420811100000.0, shape=(), dtype=float32)
# tf.Tensor(420808430000.0, shape=(), dtype=float32)
# tf.Tensor(420805700000.0, shape=(), dtype=float32)
# tf.Tensor(420802950000.0, shape=(), dtype=float32)
# tf.Tensor(420800330000.0, shape=(), dtype=float32)
# tf.Tensor(420797600000.0, shape=(), dtype=float32)
# tf.Tensor(420794930000.0, shape=(), dtype=float32)
# tf.Tensor(420792240000.0, shape=(), dtype=float32)
# tf.Tensor(420789550000.0, shape=(), dtype=float32)
# tf.Tensor(420786830000.0, shape=(), dtype=float32)
# tf.Tensor(420784140000.0, shape=(), dtype=float32)

# %%
# print the trained parameters
print(intercept.numpy(), slope.numpy())
# Out:
# 2.0983524 2.098373

# %% [markdown]
# ___
# ### Multiple linear regression (Practice Question)
# In most cases, performing a univariate linear regression will not yield a model that is useful for making accurate predictions. In this exercise, you will perform a multiple regression, which uses more than one feature.
#
# - You will use ``price_log`` as your target and ``size_log`` and ``bedrooms`` as your features. Each of these tensors has been defined and is available.
# - You will also switch from using the the mean squared error loss to the mean absolute error loss: ``keras.losses.mae()``.
# - Finally, the predicted values are computed as follows: ``params[0] + feature1*params[1] + feature2*params[2]``.
# - Note that we've defined a vector of parameters, ``params``, as a variable, rather than using three variables. Here, ``params[0]`` is the ``intercept`` and ``params[1]`` and ``params[2]`` are the ``slopes``.

# %%
# Define the linear regression model
def linear_regression(params, feature1 = size_log, feature2 = bedrooms):
    return params[0] + feature1*params[1] + feature2*params[2]

# Define the loss function
def loss_function(params, targets = price_log, feature1 = size_log, feature2 = bedrooms):
    # Set the predicted values
    predictions = linear_regression(params, feature1, feature2)
  
    # Use the mean absolute error loss
    return keras.losses.mae(targets, predictions)

# Define the optimize operation
opt = keras.optimizers.Adam()

# Perform minimization and print trainable variables
for j in range(10):
    opt.minimize(lambda: loss_function(params), var_list=[params])
    print_results(params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20820\1370547094.py in <module>
#       1 # Define the linear regression model
# ----> 2 def linear_regression(params, feature1 = size_log, feature2 = bedrooms):
#       3     return params[0] + feature1*params[1] + feature2*params[2]
#       4
#       5 # Define the loss function
#
# NameError: name 'size_log' is not defined
